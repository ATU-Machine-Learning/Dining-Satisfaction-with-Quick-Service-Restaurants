# %%
# Run this cell to ensure you ecosystem is setup correctly
# %pip install -r ../requirements.txt
# %pip install --upgrade scikit-learn threadpoolctl

import os

os.environ['OMP_NUM_THREADS'] = '3'
# Out:
# Requirement already satisfied: pandas in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 1)) (1.5.3)
# Requirement already satisfied: numpy in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 2)) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 3)) (3.7.1)
# Requirement already satisfied: seaborn in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 4)) (0.12.2)
# Requirement already satisfied: scikit-learn in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 5)) (1.2.2)
# Requirement already satisfied: threadpoolctl in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 6)) (3.1.0)
# Requirement already satisfied: openpyxl in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from -r ../requirements.txt (line 7)) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2022.7)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (23.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from matplotlib->-r ../requirements.txt (line 3)) (3.0.9)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 5)) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: et-xmlfile in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from openpyxl->-r ../requirements.txt (line 7)) (1.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from python-dateutil>=2.8.1->pandas->-r ../requirements.txt (line 1)) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-learn in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (1.2.2)
# Requirement already satisfied: threadpoolctl in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (3.1.0)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from scikit-learn) (1.23.5)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from scikit-learn) (1.10.1)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\clayt\anaconda3\envs\qsr\lib\site-packages (from scikit-learn) (1.2.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Question 1: Import the following libraries, including their `as` aliases: pandas, numpy, matplotlib (pyplot) and seaborn.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Question 2.0: Read the "QSR final dataset.xlsx" file into a pandas dataframe called `df`. 
# Question 2.1: Set the index column to be the ID column.
# NOTE: The "Unnamed: 0" column is a duplicate of the ID column, we've dropped it for you here. This is an Excel artifact.
# Question 2.2: View the first 5 rows of the dataframe.

df = pd.read_excel('../data/QSR final dataset.xlsx', index_col='ID')
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head()
# Out:
#     Zip.code  Gender  Marital  academic  Age  num.month favorite.QSR  \
# ID
# 1    72830.0       2        2         4    2          6  BURGER KING
# 2    72845.0       2        2         4    1         28  BURGER KING
# 3    72560.0       1        2         3    1         15   MCDONALD'S
# 4    71935.0       1        3         3    1          4        SONIC
# 5    72745.0       2        2         3    1          4    TACO BELL
#
#     num.people  appealing  seat  ...  drive..tru  discounts  healthy.food  \
# ID                               ...
# 1            1          3     3  ...           4          4             4
# 2            1          2     5  ...           3          2             2
# 3            1          3     3  ...           5          4             2
# 4            2          4     5  ...           5          5             2
# 5            1          5     4  ...           5          3             4
#
#     menu  last.visit  visit.again  recommend  Profession  Information.Source  \
# ID
# 1      4           5            4          4     Student        multiple.way
# 2      3           3            4          4     Student               drive
# 3      5           5            5          4     Student                sign
# 4      5           5            5          5     Student               other
# 5      5           5            5          5     Student               drive
#
#     Professional
# ID
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
#
# [5 rows x 37 columns]

# %%
# Question 3: Fill in the missing values in the dataframe with 0, but only for the numerical columns.
# Hint: loop through the dataframe's columns, if a column's data type is 'int64' or 'float64', then set the missing values to 0.
for col in df.columns:
    if df[col].dtype == 'int64' or df[col].dtype == 'float64':
        df[col] = df[col].fillna(0)

# %% [markdown]
# #### Feature Engineering

# %%
# Question 4: Complete the `calculate_total_score` function below based on the documentation string provided:
# HINT: Use `axis=1` to calculate the total score for each row, not each column.
def calculate_total_score(df, start_col_name, end_col_name):
    """
    Calculates the total score for each row in the dataframe, based on the columns passed in.

    Args:
        `df (pandas.DataFrame)`: The dataframe to calculate the total score for.
        `start_col_name (str)`: The name of the column to start the calculation from.
        `end_col_name (str)`: The name of the column to end the calculation at.

    Returns:
        pandas.DataFrame: The dataframe with the column 'Total Score' added.

    Example:
        >>> df = pandas.DataFrame({'appealing': [1, 2, 3], 'visit again': [4, 5, 6]})
        >>> df = calculate_total_score(df, 'appealing', 'visit again')
        >>> df.head()
              appealing  visit again  Total Score
        0         1            4            5
        1         2            5            7
        2         3            6            9
    """
    df['Total Score'] = df.loc[:, start_col_name:end_col_name].sum(axis=1)
    return df

# Implement the function here
df = calculate_total_score(df, 'appealing', 'visit.again')

# %% [markdown]
# #### Exploratory Data Analysis

# %%
# Question 5: Create a Matplotlib bar figure of the restaurants with perfect scores (125) and how many reviews they have.
perfect_df = df.loc[df['Total Score'] == 125]
perfect_df['favorite.QSR'].value_counts().plot(kind='bar')

plt.title('Perfect QSRs')
plt.xlabel('Restaurant')
plt.ylabel('Reviews')
plt.show()

# %%
# Question 6: Create another Matplotlib bar figure of the top 5 most picked restaurants and their average recommendation rating.
top_df = df['favorite.QSR'].value_counts().head(5)
top_df = df[df['favorite.QSR'].isin(top_df.index)]
top_df.groupby('favorite.QSR')['recommend'].mean().sort_values(ascending=False).plot(kind='bar')

plt.title('Recommendation Rating for Top 5 QSRs')
plt.xlabel('QSR')
plt.ylabel('Average Recommendation Rating')
plt.show()

# %%
# Question 7: Using the following correlated columns, create a correlation matrix heatmap of the dataset.
corr_columns = ['appealing',
       'seat', 'parking', 'cleanliness', 'appearance', 'friendliness',
       'knowledge', 'received', 'billing', 'prompt', 'attention', 'hours',
       'waiting.time', 'food.size', 'price', 'Wifi', 'Variety', 'value',
       'location', 'drive..tru', 'discounts', 'healthy.food', 'menu',
       'last.visit', 'visit.again', 'recommend', 'Total Score']

feature_df = pd.DataFrame()

for col in corr_columns:
       feature_df[col] = df[col]
       corr_matrix = feature_df.corr()

fig, ax = plt.subplots()
sns.heatmap(corr_matrix, annot=False)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# #### Modeling

# %%
from sklearn.cluster import KMeans

# %%
# Question 8: Put 'Total Score' and 'recommend' into a list called relevant_features
relevant_features = ['Total Score', 'recommend']

# Question 8.1: Set X equal to the values of the relevant_features in the dataframe.
X = df[relevant_features].values

results = []

# Question 8.2:
# Write a loop that runs through the range of 1-10 (which represents the amount of clusters)
# and fits the data in X to KMeans for each amount of cluster between 1-10.
for i in range(1,11):
    kmeans = KMeans(n_clusters=i, init="k-means++", random_state=42, n_init='auto')
    kmeans.fit(X)
    # inertia_ is the formula used to segregate the data points into clusters
    results.append(kmeans.inertia_)

# Question 8.3: Plot the results list against the range of 1-10.
plt.plot(range(1,11), results)
# Notice the plot's elbow at 3 clusters, this is the optimal amount of clusters for this dataset.

# %%
# Question 9: Create a KMeans model with 3 clusters, using the following parameters:
model = KMeans(n_clusters=3, init='k-means++', random_state=42, n_init='auto')

# Question 9.1: Fit the model to the data in X
y = model.fit_predict(X)

# %%
num_clusters = len(np.unique(y))

for cluster in range(num_clusters):
    plt.scatter(X[y == cluster, 0], X[y == cluster, 1], s=100, label=f'Cluster {cluster+1}')

plt.scatter(model.cluster_centers_[:, 0], model.cluster_centers_[:, 1], s=300, c='yellow', label='Centroids')
plt.title('QSR Clusters')
plt.xlabel('Total Score')
plt.ylabel('Recommend Score')
plt.legend()
plt.show()
